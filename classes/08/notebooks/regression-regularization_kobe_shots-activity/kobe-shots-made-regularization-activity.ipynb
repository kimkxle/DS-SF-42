# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # DS-SF-42 | Class 8 | Regression - Addressing model fit
#
# <br>
# ### _Predicting shots made per game by Kobe Bryant_
#
# _Authors: Kiefer Katovich (SF) and Gus Ostow (SF)_
#
# ---
#
# The Kobe shots dataset has hundreds of columns representing different characteristics of each basketball game. Fitting an ordinary linear regression will cause issues that other datasets might not. In this exploration you will be diagnose issues with model fit using regression metrics, train/test split, and cross validation.
#
#
# ### Plan
#
# Today I am going to flip the script: we are going to start the class with a hands-on partner activity to motivate the day's topic, then address the theory after.
#
# 1. Motivating the problem
# 3. Slides interlude
# 2. Addressing the problem
#
# ### Teams
#
# <img src=https://i.imgur.com/JI6ydY5.png align=left>
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>
#
#
# # <font color=blue>Part I</font> - Motifivating the problem
#
#
# ---
#
# ### 1. Load packages and data

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
kobe = pd.read_csv('./datasets/kobe_superwide_games.csv')

# %% [markdown]
# ---
#
# ### 2. Examine the data
#
# #### Guiding questions
#
# - How many columns are there?
# - Examine what the observations (rows) and columns represent.
# - Why does this dataset _feel_ different than the datasets we've touched so far?
# - What concerns do you have even before fitting your first model?

# %%
# A: 
kobe.shape
# Out:
# (1558, 645)

# %%
#print columns to see what values are in it

for col in kobe.columns:
    print col

# %%
kobe["AWAY_GAME"].unique()
# Out:
# array([0, 1])

# %%
#filtering and selecting only row 1 and seeing if its true or false.

kobe.filter(like="SEASON_OPPONENT").loc[0, ].astype(bool)
# Out:
# SEASON_OPPONENT:atl:1996-97    False
# SEASON_OPPONENT:atl:1997-98    False
# SEASON_OPPONENT:atl:1999-00    False
# SEASON_OPPONENT:atl:2000-01    False
# SEASON_OPPONENT:atl:2001-02    False
# SEASON_OPPONENT:atl:2002-03    False
# SEASON_OPPONENT:atl:2003-04    False
# SEASON_OPPONENT:atl:2004-05    False
# SEASON_OPPONENT:atl:2005-06    False
# SEASON_OPPONENT:atl:2006-07    False
# SEASON_OPPONENT:atl:2007-08    False
# SEASON_OPPONENT:atl:2008-09    False
# SEASON_OPPONENT:atl:2009-10    False
# SEASON_OPPONENT:atl:2010-11    False
# SEASON_OPPONENT:atl:2011-12    False
# SEASON_OPPONENT:atl:2012-13    False
# SEASON_OPPONENT:atl:2013-14    False
# SEASON_OPPONENT:atl:2014-15    False
# SEASON_OPPONENT:atl:2015-16    False
# SEASON_OPPONENT:bkn:2012-13    False
# SEASON_OPPONENT:bkn:2015-16    False
# SEASON_OPPONENT:bos:1996-97    False
# SEASON_OPPONENT:bos:1997-98    False
# SEASON_OPPONENT:bos:1999-00    False
# SEASON_OPPONENT:bos:2001-02    False
# SEASON_OPPONENT:bos:2002-03    False
# SEASON_OPPONENT:bos:2003-04    False
# SEASON_OPPONENT:bos:2004-05    False
# SEASON_OPPONENT:bos:2005-06    False
# SEASON_OPPONENT:bos:2006-07    False
#                                ...
# SEASON_OPPONENT:uta:2007-08    False
# SEASON_OPPONENT:uta:2008-09    False
# SEASON_OPPONENT:uta:2009-10    False
# SEASON_OPPONENT:uta:2010-11    False
# SEASON_OPPONENT:uta:2011-12    False
# SEASON_OPPONENT:uta:2012-13    False
# SEASON_OPPONENT:uta:2015-16    False
# SEASON_OPPONENT:van:1996-97    False
# SEASON_OPPONENT:van:1997-98    False
# SEASON_OPPONENT:van:1998-99    False
# SEASON_OPPONENT:van:1999-00    False
# SEASON_OPPONENT:van:2000-01    False
# SEASON_OPPONENT:was:1996-97    False
# SEASON_OPPONENT:was:1997-98    False
# SEASON_OPPONENT:was:1999-00    False
# SEASON_OPPONENT:was:2000-01    False
# SEASON_OPPONENT:was:2001-02    False
# SEASON_OPPONENT:was:2002-03    False
# SEASON_OPPONENT:was:2003-04    False
# SEASON_OPPONENT:was:2004-05    False
# SEASON_OPPONENT:was:2005-06    False
# SEASON_OPPONENT:was:2006-07    False
# SEASON_OPPONENT:was:2007-08    False
# SEASON_OPPONENT:was:2008-09    False
# SEASON_OPPONENT:was:2009-10    False
# SEASON_OPPONENT:was:2010-11    False
# SEASON_OPPONENT:was:2011-12    False
# SEASON_OPPONENT:was:2012-13    False
# SEASON_OPPONENT:was:2014-15    False
# SEASON_OPPONENT:was:2015-16    False
# Name: 0, Length: 529, dtype: bool

# %%
#filtering and selecting only row 1 and seeing if its true or false.

column_mask = kobe.filter(like="SEASON_OPPONENT").loc[0, ] > 0

# %%
column_mask = kobe.filter(like="SEASON_OPPONENT").loc[0, column_mask] > 0

# %%
#A: drop the column "shots made" to run the predictions for all other variables. 

kobe.columns

kobe.columns.values
# Out:
# array(['SHOTS_MADE', 'AWAY_GAME', 'SEASON_OPPONENT:atl:1996-97',
#        'SEASON_OPPONENT:atl:1997-98', 'SEASON_OPPONENT:atl:1999-00',
#        'SEASON_OPPONENT:atl:2000-01', 'SEASON_OPPONENT:atl:2001-02',
#        'SEASON_OPPONENT:atl:2002-03', 'SEASON_OPPONENT:atl:2003-04',
#        'SEASON_OPPONENT:atl:2004-05', 'SEASON_OPPONENT:atl:2005-06',
#        'SEASON_OPPONENT:atl:2006-07', 'SEASON_OPPONENT:atl:2007-08',
#        'SEASON_OPPONENT:atl:2008-09', 'SEASON_OPPONENT:atl:2009-10',
#        'SEASON_OPPONENT:atl:2010-11', 'SEASON_OPPONENT:atl:2011-12',
#        'SEASON_OPPONENT:atl:2012-13', 'SEASON_OPPONENT:atl:2013-14',
#        'SEASON_OPPONENT:atl:2014-15', 'SEASON_OPPONENT:atl:2015-16',
#        'SEASON_OPPONENT:bkn:2012-13', 'SEASON_OPPONENT:bkn:2015-16',
#        'SEASON_OPPONENT:bos:1996-97', 'SEASON_OPPONENT:bos:1997-98',
#        'SEASON_OPPONENT:bos:1999-00', 'SEASON_OPPONENT:bos:2001-02',
#        'SEASON_OPPONENT:bos:2002-03', 'SEASON_OPPONENT:bos:2003-04',
#        'SEASON_OPPONENT:bos:2004-05', 'SEASON_OPPONENT:bos:2005-06',
#        'SEASON_OPPONENT:bos:2006-07', 'SEASON_OPPONENT:bos:2007-08',
#        'SEASON_OPPONENT:bos:2008-09', 'SEASON_OPPONENT:bos:2009-10',
#        'SEASON_OPPONENT:bos:2010-11', 'SEASON_OPPONENT:bos:2011-12',
#        'SEASON_OPPONENT:bos:2012-13', 'SEASON_OPPONENT:bos:2014-15',
#        'SEASON_OPPONENT:bos:2015-16', 'SEASON_OPPONENT:cha:1996-97',
#        'SEASON_OPPONENT:cha:1997-98', 'SEASON_OPPONENT:cha:1998-99',
#        'SEASON_OPPONENT:cha:1999-00', 'SEASON_OPPONENT:cha:2000-01',
#        'SEASON_OPPONENT:cha:2001-02', 'SEASON_OPPONENT:cha:2004-05',
#        'SEASON_OPPONENT:cha:2005-06', 'SEASON_OPPONENT:cha:2006-07',
#        'SEASON_OPPONENT:cha:2007-08', 'SEASON_OPPONENT:cha:2008-09',
#        'SEASON_OPPONENT:cha:2009-10', 'SEASON_OPPONENT:cha:2010-11',
#        'SEASON_OPPONENT:cha:2011-12', 'SEASON_OPPONENT:cha:2012-13',
#        'SEASON_OPPONENT:cha:2013-14', 'SEASON_OPPONENT:cha:2014-15',
#        'SEASON_OPPONENT:cha:2015-16', 'SEASON_OPPONENT:chi:1996-97',
#        'SEASON_OPPONENT:chi:1997-98', 'SEASON_OPPONENT:chi:1999-00',
#        'SEASON_OPPONENT:chi:2000-01', 'SEASON_OPPONENT:chi:2001-02',
#        'SEASON_OPPONENT:chi:2002-03', 'SEASON_OPPONENT:chi:2003-04',
#        'SEASON_OPPONENT:chi:2004-05', 'SEASON_OPPONENT:chi:2005-06',
#        'SEASON_OPPONENT:chi:2006-07', 'SEASON_OPPONENT:chi:2007-08',
#        'SEASON_OPPONENT:chi:2008-09', 'SEASON_OPPONENT:chi:2009-10',
#        'SEASON_OPPONENT:chi:2010-11', 'SEASON_OPPONENT:chi:2011-12',
#        'SEASON_OPPONENT:chi:2012-13', 'SEASON_OPPONENT:chi:2015-16',
#        'SEASON_OPPONENT:cle:1996-97', 'SEASON_OPPONENT:cle:1997-98',
#        'SEASON_OPPONENT:cle:1998-99', 'SEASON_OPPONENT:cle:1999-00',
#        'SEASON_OPPONENT:cle:2000-01', 'SEASON_OPPONENT:cle:2001-02',
#        'SEASON_OPPONENT:cle:2002-03', 'SEASON_OPPONENT:cle:2003-04',
#        'SEASON_OPPONENT:cle:2004-05', 'SEASON_OPPONENT:cle:2005-06',
#        'SEASON_OPPONENT:cle:2006-07', 'SEASON_OPPONENT:cle:2007-08',
#        'SEASON_OPPONENT:cle:2008-09', 'SEASON_OPPONENT:cle:2009-10',
#        'SEASON_OPPONENT:cle:2010-11', 'SEASON_OPPONENT:cle:2011-12',
#        'SEASON_OPPONENT:cle:2012-13', 'SEASON_OPPONENT:cle:2014-15',
#        'SEASON_OPPONENT:cle:2015-16', 'SEASON_OPPONENT:dal:1996-97',
#        'SEASON_OPPONENT:dal:1997-98', 'SEASON_OPPONENT:dal:1998-99',
#        'SEASON_OPPONENT:dal:1999-00', 'SEASON_OPPONENT:dal:2000-01',
#        'SEASON_OPPONENT:dal:2001-02', 'SEASON_OPPONENT:dal:2002-03',
#        'SEASON_OPPONENT:dal:2003-04', 'SEASON_OPPONENT:dal:2004-05',
#        'SEASON_OPPONENT:dal:2005-06', 'SEASON_OPPONENT:dal:2006-07',
#        'SEASON_OPPONENT:dal:2007-08', 'SEASON_OPPONENT:dal:2008-09',
#        'SEASON_OPPONENT:dal:2009-10', 'SEASON_OPPONENT:dal:2010-11',
#        'SEASON_OPPONENT:dal:2011-12', 'SEASON_OPPONENT:dal:2012-13',
#        'SEASON_OPPONENT:dal:2014-15', 'SEASON_OPPONENT:dal:2015-16',
#        'SEASON_OPPONENT:den:1996-97', 'SEASON_OPPONENT:den:1997-98',
#        'SEASON_OPPONENT:den:1998-99', 'SEASON_OPPONENT:den:1999-00',
#        'SEASON_OPPONENT:den:2000-01', 'SEASON_OPPONENT:den:2001-02',
#        'SEASON_OPPONENT:den:2002-03', 'SEASON_OPPONENT:den:2003-04',
#        'SEASON_OPPONENT:den:2004-05', 'SEASON_OPPONENT:den:2005-06',
#        'SEASON_OPPONENT:den:2006-07', 'SEASON_OPPONENT:den:2007-08',
#        'SEASON_OPPONENT:den:2008-09', 'SEASON_OPPONENT:den:2009-10',
#        'SEASON_OPPONENT:den:2010-11', 'SEASON_OPPONENT:den:2011-12',
#        'SEASON_OPPONENT:den:2012-13', 'SEASON_OPPONENT:den:2014-15',
#        'SEASON_OPPONENT:den:2015-16', 'SEASON_OPPONENT:det:1996-97',
#        'SEASON_OPPONENT:det:1997-98', 'SEASON_OPPONENT:det:1999-00',
#        'SEASON_OPPONENT:det:2000-01', 'SEASON_OPPONENT:det:2001-02',
#        'SEASON_OPPONENT:det:2002-03', 'SEASON_OPPONENT:det:2003-04',
#        'SEASON_OPPONENT:det:2004-05', 'SEASON_OPPONENT:det:2005-06',
#        'SEASON_OPPONENT:det:2006-07', 'SEASON_OPPONENT:det:2007-08',
#        'SEASON_OPPONENT:det:2008-09', 'SEASON_OPPONENT:det:2009-10',
#        'SEASON_OPPONENT:det:2010-11', 'SEASON_OPPONENT:det:2011-12',
#        'SEASON_OPPONENT:det:2012-13', 'SEASON_OPPONENT:det:2014-15',
#        'SEASON_OPPONENT:det:2015-16', 'SEASON_OPPONENT:gsw:1996-97',
#        'SEASON_OPPONENT:gsw:1997-98', 'SEASON_OPPONENT:gsw:1998-99',
#        'SEASON_OPPONENT:gsw:1999-00', 'SEASON_OPPONENT:gsw:2000-01',
#        'SEASON_OPPONENT:gsw:2001-02', 'SEASON_OPPONENT:gsw:2002-03',
#        'SEASON_OPPONENT:gsw:2003-04', 'SEASON_OPPONENT:gsw:2004-05',
#        'SEASON_OPPONENT:gsw:2005-06', 'SEASON_OPPONENT:gsw:2006-07',
#        'SEASON_OPPONENT:gsw:2007-08', 'SEASON_OPPONENT:gsw:2008-09',
#        'SEASON_OPPONENT:gsw:2009-10', 'SEASON_OPPONENT:gsw:2010-11',
#        'SEASON_OPPONENT:gsw:2011-12', 'SEASON_OPPONENT:gsw:2012-13',
#        'SEASON_OPPONENT:gsw:2014-15', 'SEASON_OPPONENT:gsw:2015-16',
#        'SEASON_OPPONENT:hou:1996-97', 'SEASON_OPPONENT:hou:1997-98',
#        'SEASON_OPPONENT:hou:1998-99', 'SEASON_OPPONENT:hou:1999-00',
#        'SEASON_OPPONENT:hou:2000-01', 'SEASON_OPPONENT:hou:2001-02',
#        'SEASON_OPPONENT:hou:2002-03', 'SEASON_OPPONENT:hou:2003-04',
#        'SEASON_OPPONENT:hou:2004-05', 'SEASON_OPPONENT:hou:2005-06',
#        'SEASON_OPPONENT:hou:2006-07', 'SEASON_OPPONENT:hou:2007-08',
#        'SEASON_OPPONENT:hou:2008-09', 'SEASON_OPPONENT:hou:2009-10',
#        'SEASON_OPPONENT:hou:2010-11', 'SEASON_OPPONENT:hou:2011-12',
#        'SEASON_OPPONENT:hou:2012-13', 'SEASON_OPPONENT:hou:2014-15',
#        'SEASON_OPPONENT:hou:2015-16', 'SEASON_OPPONENT:ind:1996-97',
#        'SEASON_OPPONENT:ind:1997-98', 'SEASON_OPPONENT:ind:1998-99',
#        'SEASON_OPPONENT:ind:1999-00', 'SEASON_OPPONENT:ind:2000-01',
#        'SEASON_OPPONENT:ind:2001-02', 'SEASON_OPPONENT:ind:2002-03',
#        'SEASON_OPPONENT:ind:2003-04', 'SEASON_OPPONENT:ind:2004-05',
#        'SEASON_OPPONENT:ind:2005-06', 'SEASON_OPPONENT:ind:2006-07',
#        'SEASON_OPPONENT:ind:2007-08', 'SEASON_OPPONENT:ind:2008-09',
#        'SEASON_OPPONENT:ind:2009-10', 'SEASON_OPPONENT:ind:2010-11',
#        'SEASON_OPPONENT:ind:2011-12', 'SEASON_OPPONENT:ind:2012-13',
#        'SEASON_OPPONENT:ind:2014-15', 'SEASON_OPPONENT:ind:2015-16',
#        'SEASON_OPPONENT:lac:1996-97', 'SEASON_OPPONENT:lac:1997-98',
#        'SEASON_OPPONENT:lac:1998-99', 'SEASON_OPPONENT:lac:1999-00',
#        'SEASON_OPPONENT:lac:2000-01', 'SEASON_OPPONENT:lac:2001-02',
#        'SEASON_OPPONENT:lac:2002-03', 'SEASON_OPPONENT:lac:2003-04',
#        'SEASON_OPPONENT:lac:2004-05', 'SEASON_OPPONENT:lac:2005-06',
#        'SEASON_OPPONENT:lac:2006-07', 'SEASON_OPPONENT:lac:2007-08',
#        'SEASON_OPPONENT:lac:2008-09', 'SEASON_OPPONENT:lac:2009-10',
#        'SEASON_OPPONENT:lac:2010-11', 'SEASON_OPPONENT:lac:2011-12',
#        'SEASON_OPPONENT:lac:2012-13', 'SEASON_OPPONENT:lac:2014-15',
#        'SEASON_OPPONENT:lac:2015-16', 'SEASON_OPPONENT:mem:2001-02',
#        'SEASON_OPPONENT:mem:2002-03', 'SEASON_OPPONENT:mem:2003-04',
#        'SEASON_OPPONENT:mem:2004-05', 'SEASON_OPPONENT:mem:2005-06',
#        'SEASON_OPPONENT:mem:2006-07', 'SEASON_OPPONENT:mem:2007-08',
#        'SEASON_OPPONENT:mem:2008-09', 'SEASON_OPPONENT:mem:2009-10',
#        'SEASON_OPPONENT:mem:2010-11', 'SEASON_OPPONENT:mem:2011-12',
#        'SEASON_OPPONENT:mem:2012-13', 'SEASON_OPPONENT:mem:2013-14',
#        'SEASON_OPPONENT:mem:2014-15', 'SEASON_OPPONENT:mem:2015-16',
#        'SEASON_OPPONENT:mia:1996-97', 'SEASON_OPPONENT:mia:1997-98',
#        'SEASON_OPPONENT:mia:1999-00', 'SEASON_OPPONENT:mia:2000-01',
#        'SEASON_OPPONENT:mia:2001-02', 'SEASON_OPPONENT:mia:2002-03',
#        'SEASON_OPPONENT:mia:2003-04', 'SEASON_OPPONENT:mia:2004-05',
#        'SEASON_OPPONENT:mia:2005-06', 'SEASON_OPPONENT:mia:2006-07',
#        'SEASON_OPPONENT:mia:2007-08', 'SEASON_OPPONENT:mia:2008-09',
#        'SEASON_OPPONENT:mia:2009-10', 'SEASON_OPPONENT:mia:2010-11',
#        'SEASON_OPPONENT:mia:2011-12', 'SEASON_OPPONENT:mia:2012-13',
#        'SEASON_OPPONENT:mia:2014-15', 'SEASON_OPPONENT:mia:2015-16',
#        'SEASON_OPPONENT:mil:1996-97', 'SEASON_OPPONENT:mil:1997-98',
#        'SEASON_OPPONENT:mil:1999-00', 'SEASON_OPPONENT:mil:2000-01',
#        'SEASON_OPPONENT:mil:2001-02', 'SEASON_OPPONENT:mil:2002-03',
#        'SEASON_OPPONENT:mil:2003-04', 'SEASON_OPPONENT:mil:2004-05',
#        'SEASON_OPPONENT:mil:2005-06', 'SEASON_OPPONENT:mil:2006-07',
#        'SEASON_OPPONENT:mil:2007-08', 'SEASON_OPPONENT:mil:2008-09',
#        'SEASON_OPPONENT:mil:2009-10', 'SEASON_OPPONENT:mil:2010-11',
#        'SEASON_OPPONENT:mil:2011-12', 'SEASON_OPPONENT:mil:2012-13',
#        'SEASON_OPPONENT:mil:2015-16', 'SEASON_OPPONENT:min:1996-97',
#        'SEASON_OPPONENT:min:1997-98', 'SEASON_OPPONENT:min:1998-99',
#        'SEASON_OPPONENT:min:1999-00', 'SEASON_OPPONENT:min:2000-01',
#        'SEASON_OPPONENT:min:2001-02', 'SEASON_OPPONENT:min:2002-03',
#        'SEASON_OPPONENT:min:2003-04', 'SEASON_OPPONENT:min:2004-05',
#        'SEASON_OPPONENT:min:2005-06', 'SEASON_OPPONENT:min:2006-07',
#        'SEASON_OPPONENT:min:2007-08', 'SEASON_OPPONENT:min:2008-09',
#        'SEASON_OPPONENT:min:2009-10', 'SEASON_OPPONENT:min:2010-11',
#        'SEASON_OPPONENT:min:2011-12', 'SEASON_OPPONENT:min:2012-13',
#        'SEASON_OPPONENT:min:2014-15', 'SEASON_OPPONENT:min:2015-16',
#        'SEASON_OPPONENT:njn:1996-97', 'SEASON_OPPONENT:njn:1997-98',
#        'SEASON_OPPONENT:njn:1999-00', 'SEASON_OPPONENT:njn:2000-01',
#        'SEASON_OPPONENT:njn:2001-02', 'SEASON_OPPONENT:njn:2002-03',
#        'SEASON_OPPONENT:njn:2003-04', 'SEASON_OPPONENT:njn:2005-06',
#        'SEASON_OPPONENT:njn:2006-07', 'SEASON_OPPONENT:njn:2007-08',
#        'SEASON_OPPONENT:njn:2008-09', 'SEASON_OPPONENT:njn:2009-10',
#        'SEASON_OPPONENT:njn:2010-11', 'SEASON_OPPONENT:njn:2011-12',
#        'SEASON_OPPONENT:noh:2002-03', 'SEASON_OPPONENT:noh:2003-04',
#        'SEASON_OPPONENT:noh:2007-08', 'SEASON_OPPONENT:noh:2008-09',
#        'SEASON_OPPONENT:noh:2009-10', 'SEASON_OPPONENT:noh:2010-11',
#        'SEASON_OPPONENT:noh:2011-12', 'SEASON_OPPONENT:noh:2012-13',
#        'SEASON_OPPONENT:nop:2004-05', 'SEASON_OPPONENT:nop:2005-06',
#        'SEASON_OPPONENT:nop:2006-07', 'SEASON_OPPONENT:nop:2014-15',
#        'SEASON_OPPONENT:nop:2015-16', 'SEASON_OPPONENT:nyk:1996-97',
#        'SEASON_OPPONENT:nyk:1997-98', 'SEASON_OPPONENT:nyk:1998-99',
#        'SEASON_OPPONENT:nyk:1999-00', 'SEASON_OPPONENT:nyk:2000-01',
#        'SEASON_OPPONENT:nyk:2001-02', 'SEASON_OPPONENT:nyk:2002-03',
#        'SEASON_OPPONENT:nyk:2003-04', 'SEASON_OPPONENT:nyk:2004-05',
#        'SEASON_OPPONENT:nyk:2005-06', 'SEASON_OPPONENT:nyk:2006-07',
#        'SEASON_OPPONENT:nyk:2007-08', 'SEASON_OPPONENT:nyk:2008-09',
#        'SEASON_OPPONENT:nyk:2009-10', 'SEASON_OPPONENT:nyk:2010-11',
#        'SEASON_OPPONENT:nyk:2011-12', 'SEASON_OPPONENT:nyk:2012-13',
#        'SEASON_OPPONENT:nyk:2015-16', 'SEASON_OPPONENT:okc:2008-09',
#        'SEASON_OPPONENT:okc:2009-10', 'SEASON_OPPONENT:okc:2010-11',
#        'SEASON_OPPONENT:okc:2011-12', 'SEASON_OPPONENT:okc:2012-13',
#        'SEASON_OPPONENT:okc:2013-14', 'SEASON_OPPONENT:okc:2014-15',
#        'SEASON_OPPONENT:okc:2015-16', 'SEASON_OPPONENT:orl:1996-97',
#        'SEASON_OPPONENT:orl:1997-98', 'SEASON_OPPONENT:orl:1998-99',
#        'SEASON_OPPONENT:orl:1999-00', 'SEASON_OPPONENT:orl:2000-01',
#        'SEASON_OPPONENT:orl:2001-02', 'SEASON_OPPONENT:orl:2002-03',
#        'SEASON_OPPONENT:orl:2003-04', 'SEASON_OPPONENT:orl:2004-05',
#        'SEASON_OPPONENT:orl:2005-06', 'SEASON_OPPONENT:orl:2006-07',
#        'SEASON_OPPONENT:orl:2007-08', 'SEASON_OPPONENT:orl:2008-09',
#        'SEASON_OPPONENT:orl:2009-10', 'SEASON_OPPONENT:orl:2010-11',
#        'SEASON_OPPONENT:orl:2011-12', 'SEASON_OPPONENT:orl:2012-13',
#        'SEASON_OPPONENT:phi:1996-97', 'SEASON_OPPONENT:phi:1997-98',
#        'SEASON_OPPONENT:phi:1998-99', 'SEASON_OPPONENT:phi:1999-00',
#        'SEASON_OPPONENT:phi:2000-01', 'SEASON_OPPONENT:phi:2001-02',
#        'SEASON_OPPONENT:phi:2002-03', 'SEASON_OPPONENT:phi:2003-04',
#        'SEASON_OPPONENT:phi:2004-05', 'SEASON_OPPONENT:phi:2005-06',
#        'SEASON_OPPONENT:phi:2006-07', 'SEASON_OPPONENT:phi:2007-08',
#        'SEASON_OPPONENT:phi:2008-09', 'SEASON_OPPONENT:phi:2009-10',
#        'SEASON_OPPONENT:phi:2010-11', 'SEASON_OPPONENT:phi:2011-12',
#        'SEASON_OPPONENT:phi:2012-13', 'SEASON_OPPONENT:phi:2015-16',
#        'SEASON_OPPONENT:phx:1996-97', 'SEASON_OPPONENT:phx:1997-98',
#        'SEASON_OPPONENT:phx:1998-99', 'SEASON_OPPONENT:phx:1999-00',
#        'SEASON_OPPONENT:phx:2000-01', 'SEASON_OPPONENT:phx:2001-02',
#        'SEASON_OPPONENT:phx:2002-03', 'SEASON_OPPONENT:phx:2003-04',
#        'SEASON_OPPONENT:phx:2004-05', 'SEASON_OPPONENT:phx:2005-06',
#        'SEASON_OPPONENT:phx:2006-07', 'SEASON_OPPONENT:phx:2007-08',
#        'SEASON_OPPONENT:phx:2008-09', 'SEASON_OPPONENT:phx:2009-10',
#        'SEASON_OPPONENT:phx:2010-11', 'SEASON_OPPONENT:phx:2011-12',
#        'SEASON_OPPONENT:phx:2012-13', 'SEASON_OPPONENT:phx:2013-14',
#        'SEASON_OPPONENT:phx:2014-15', 'SEASON_OPPONENT:phx:2015-16',
#        'SEASON_OPPONENT:por:1996-97', 'SEASON_OPPONENT:por:1997-98',
#        'SEASON_OPPONENT:por:1998-99', 'SEASON_OPPONENT:por:1999-00',
#        'SEASON_OPPONENT:por:2000-01', 'SEASON_OPPONENT:por:2001-02',
#        'SEASON_OPPONENT:por:2002-03', 'SEASON_OPPONENT:por:2003-04',
#        'SEASON_OPPONENT:por:2004-05', 'SEASON_OPPONENT:por:2005-06',
#        'SEASON_OPPONENT:por:2006-07', 'SEASON_OPPONENT:por:2007-08',
#        'SEASON_OPPONENT:por:2008-09', 'SEASON_OPPONENT:por:2009-10',
#        'SEASON_OPPONENT:por:2010-11', 'SEASON_OPPONENT:por:2011-12',
#        'SEASON_OPPONENT:por:2012-13', 'SEASON_OPPONENT:por:2015-16',
#        'SEASON_OPPONENT:sac:1996-97', 'SEASON_OPPONENT:sac:1997-98',
#        'SEASON_OPPONENT:sac:1998-99', 'SEASON_OPPONENT:sac:1999-00',
#        'SEASON_OPPONENT:sac:2000-01', 'SEASON_OPPONENT:sac:2001-02',
#        'SEASON_OPPONENT:sac:2002-03', 'SEASON_OPPONENT:sac:2003-04',
#        'SEASON_OPPONENT:sac:2004-05', 'SEASON_OPPONENT:sac:2005-06',
#        'SEASON_OPPONENT:sac:2006-07', 'SEASON_OPPONENT:sac:2007-08',
#        'SEASON_OPPONENT:sac:2008-09', 'SEASON_OPPONENT:sac:2009-10',
#        'SEASON_OPPONENT:sac:2010-11', 'SEASON_OPPONENT:sac:2011-12',
#        'SEASON_OPPONENT:sac:2012-13', 'SEASON_OPPONENT:sac:2014-15',
#        'SEASON_OPPONENT:sac:2015-16', 'SEASON_OPPONENT:sas:1996-97',
#        'SEASON_OPPONENT:sas:1997-98', 'SEASON_OPPONENT:sas:1998-99',
#        'SEASON_OPPONENT:sas:1999-00', 'SEASON_OPPONENT:sas:2000-01',
#        'SEASON_OPPONENT:sas:2001-02', 'SEASON_OPPONENT:sas:2002-03',
#        'SEASON_OPPONENT:sas:2003-04', 'SEASON_OPPONENT:sas:2004-05',
#        'SEASON_OPPONENT:sas:2005-06', 'SEASON_OPPONENT:sas:2006-07',
#        'SEASON_OPPONENT:sas:2007-08', 'SEASON_OPPONENT:sas:2008-09',
#        'SEASON_OPPONENT:sas:2009-10', 'SEASON_OPPONENT:sas:2010-11',
#        'SEASON_OPPONENT:sas:2011-12', 'SEASON_OPPONENT:sas:2012-13',
#        'SEASON_OPPONENT:sas:2014-15', 'SEASON_OPPONENT:sas:2015-16',
#        'SEASON_OPPONENT:sea:1996-97', 'SEASON_OPPONENT:sea:1997-98',
#        'SEASON_OPPONENT:sea:1998-99', 'SEASON_OPPONENT:sea:1999-00',
#        'SEASON_OPPONENT:sea:2000-01', 'SEASON_OPPONENT:sea:2001-02',
#        'SEASON_OPPONENT:sea:2002-03', 'SEASON_OPPONENT:sea:2003-04',
#        'SEASON_OPPONENT:sea:2004-05', 'SEASON_OPPONENT:sea:2005-06',
#        'SEASON_OPPONENT:sea:2006-07', 'SEASON_OPPONENT:sea:2007-08',
#        'SEASON_OPPONENT:tor:1996-97', 'SEASON_OPPONENT:tor:1997-98',
#        'SEASON_OPPONENT:tor:1999-00', 'SEASON_OPPONENT:tor:2000-01',
#        'SEASON_OPPONENT:tor:2001-02', 'SEASON_OPPONENT:tor:2002-03',
#        'SEASON_OPPONENT:tor:2003-04', 'SEASON_OPPONENT:tor:2004-05',
#        'SEASON_OPPONENT:tor:2005-06', 'SEASON_OPPONENT:tor:2006-07',
#        'SEASON_OPPONENT:tor:2007-08', 'SEASON_OPPONENT:tor:2008-09',
#        'SEASON_OPPONENT:tor:2009-10', 'SEASON_OPPONENT:tor:2010-11',
#        'SEASON_OPPONENT:tor:2011-12', 'SEASON_OPPONENT:tor:2012-13',
#        'SEASON_OPPONENT:tor:2013-14', 'SEASON_OPPONENT:tor:2014-15',
#        'SEASON_OPPONENT:tor:2015-16', 'SEASON_OPPONENT:uta:1996-97',
#        'SEASON_OPPONENT:uta:1997-98', 'SEASON_OPPONENT:uta:1998-99',
#        'SEASON_OPPONENT:uta:1999-00', 'SEASON_OPPONENT:uta:2000-01',
#        'SEASON_OPPONENT:uta:2001-02', 'SEASON_OPPONENT:uta:2002-03',
#        'SEASON_OPPONENT:uta:2003-04', 'SEASON_OPPONENT:uta:2004-05',
#        'SEASON_OPPONENT:uta:2005-06', 'SEASON_OPPONENT:uta:2006-07',
#        'SEASON_OPPONENT:uta:2007-08', 'SEASON_OPPONENT:uta:2008-09',
#        'SEASON_OPPONENT:uta:2009-10', 'SEASON_OPPONENT:uta:2010-11',
#        'SEASON_OPPONENT:uta:2011-12', 'SEASON_OPPONENT:uta:2012-13',
#        'SEASON_OPPONENT:uta:2015-16', 'SEASON_OPPONENT:van:1996-97',
#        'SEASON_OPPONENT:van:1997-98', 'SEASON_OPPONENT:van:1998-99',
#        'SEASON_OPPONENT:van:1999-00', 'SEASON_OPPONENT:van:2000-01',
#        'SEASON_OPPONENT:was:1996-97', 'SEASON_OPPONENT:was:1997-98',
#        'SEASON_OPPONENT:was:1999-00', 'SEASON_OPPONENT:was:2000-01',
#        'SEASON_OPPONENT:was:2001-02', 'SEASON_OPPONENT:was:2002-03',
#        'SEASON_OPPONENT:was:2003-04', 'SEASON_OPPONENT:was:2004-05',
#        'SEASON_OPPONENT:was:2005-06', 'SEASON_OPPONENT:was:2006-07',
#        'SEASON_OPPONENT:was:2007-08', 'SEASON_OPPONENT:was:2008-09',
#        'SEASON_OPPONENT:was:2009-10', 'SEASON_OPPONENT:was:2010-11',
#        'SEASON_OPPONENT:was:2011-12', 'SEASON_OPPONENT:was:2012-13',
#        'SEASON_OPPONENT:was:2014-15', 'SEASON_OPPONENT:was:2015-16',
#        'SEASON:1996-97', 'SEASON:1997-98', 'SEASON:1998-99',
#        'SEASON:1999-00', 'SEASON:2000-01', 'SEASON:2001-02',
#        'SEASON:2002-03', 'SEASON:2003-04', 'SEASON:2004-05',
#        'SEASON:2005-06', 'SEASON:2006-07', 'SEASON:2007-08',
#        'SEASON:2008-09', 'SEASON:2009-10', 'SEASON:2010-11',
#        'SEASON:2011-12', 'SEASON:2012-13', 'SEASON:2013-14',
#        'SEASON:2014-15', 'SEASON:2015-16', 'MONTH', 'PLAYOFFS',
#        'MEAN_X_POSITION', 'MEAN_Y_POSITION', 'MEAN_SHOT_DISTANCE',
#        'MEAN_SHOT_ANGLE', 'SHOT_ZONE_RANGE:16-24_ft.',
#        'SHOT_ZONE_RANGE:24+_ft.', 'SHOT_ZONE_RANGE:8-16_ft.',
#        'SHOT_ZONE_RANGE:back_court_shot',
#        'SHOT_ZONE_RANGE:less_than_8_ft.',
#        'SHOT_ZONE_BASIC:above_the_break_3', 'SHOT_ZONE_BASIC:backcourt',
#        'SHOT_ZONE_BASIC:in_the_paint_(non-ra)',
#        'SHOT_ZONE_BASIC:left_corner_3', 'SHOT_ZONE_BASIC:mid-range',
#        'SHOT_ZONE_BASIC:restricted_area', 'SHOT_ZONE_BASIC:right_corner_3',
#        'SHOT_ZONE_AREA:back_court(bc)', 'SHOT_ZONE_AREA:center(c)',
#        'SHOT_ZONE_AREA:left_side_center(lc)',
#        'SHOT_ZONE_AREA:left_side(l)',
#        'SHOT_ZONE_AREA:right_side_center(rc)',
#        'SHOT_ZONE_AREA:right_side(r)', 'SHOT_TYPE:2pt_field_goal',
#        'SHOT_TYPE:3pt_field_goal', 'COMBINED_SHOT_TYPE:bank_shot',
#        'COMBINED_SHOT_TYPE:dunk', 'COMBINED_SHOT_TYPE:hook_shot',
#        'COMBINED_SHOT_TYPE:jump_shot', 'COMBINED_SHOT_TYPE:layup',
#        'COMBINED_SHOT_TYPE:tip_shot', 'SECONDS_REMAINING',
#        'MINUTES_REMAINING', 'PERIOD', 'ACTION_TYPE:alley_oop_dunk_shot',
#        'ACTION_TYPE:alley_oop_layup_shot',
#        'ACTION_TYPE:cutting_finger_roll_layup_shot',
#        'ACTION_TYPE:cutting_layup_shot', 'ACTION_TYPE:driving_bank_shot',
#        'ACTION_TYPE:driving_dunk_shot',
#        'ACTION_TYPE:driving_finger_roll_layup_shot',
#        'ACTION_TYPE:driving_finger_roll_shot',
#        'ACTION_TYPE:driving_floating_bank_jump_shot',
#        'ACTION_TYPE:driving_floating_jump_shot',
#        'ACTION_TYPE:driving_hook_shot', 'ACTION_TYPE:driving_jump_shot',
#        'ACTION_TYPE:driving_layup_shot',
#        'ACTION_TYPE:driving_reverse_layup_shot',
#        'ACTION_TYPE:driving_slam_dunk_shot', 'ACTION_TYPE:dunk_shot',
#        'ACTION_TYPE:fadeaway_bank_shot', 'ACTION_TYPE:fadeaway_jump_shot',
#        'ACTION_TYPE:finger_roll_layup_shot',
#        'ACTION_TYPE:finger_roll_shot', 'ACTION_TYPE:floating_jump_shot',
#        'ACTION_TYPE:follow_up_dunk_shot', 'ACTION_TYPE:hook_bank_shot',
#        'ACTION_TYPE:hook_shot', 'ACTION_TYPE:jump_bank_shot',
#        'ACTION_TYPE:jump_hook_shot', 'ACTION_TYPE:jump_shot',
#        'ACTION_TYPE:layup_shot', 'ACTION_TYPE:pullup_bank_shot',
#        'ACTION_TYPE:pullup_jump_shot', 'ACTION_TYPE:putback_dunk_shot',
#        'ACTION_TYPE:putback_layup_shot',
#        'ACTION_TYPE:putback_slam_dunk_shot',
#        'ACTION_TYPE:reverse_dunk_shot', 'ACTION_TYPE:reverse_layup_shot',
#        'ACTION_TYPE:reverse_slam_dunk_shot',
#        'ACTION_TYPE:running_bank_shot', 'ACTION_TYPE:running_dunk_shot',
#        'ACTION_TYPE:running_finger_roll_layup_shot',
#        'ACTION_TYPE:running_finger_roll_shot',
#        'ACTION_TYPE:running_hook_shot', 'ACTION_TYPE:running_jump_shot',
#        'ACTION_TYPE:running_layup_shot',
#        'ACTION_TYPE:running_pull-up_jump_shot',
#        'ACTION_TYPE:running_reverse_layup_shot',
#        'ACTION_TYPE:running_slam_dunk_shot',
#        'ACTION_TYPE:running_tip_shot', 'ACTION_TYPE:slam_dunk_shot',
#        'ACTION_TYPE:step_back_jump_shot', 'ACTION_TYPE:tip_layup_shot',
#        'ACTION_TYPE:tip_shot', 'ACTION_TYPE:turnaround_bank_shot',
#        'ACTION_TYPE:turnaround_fadeaway_bank_jump_shot',
#        'ACTION_TYPE:turnaround_fadeaway_shot',
#        'ACTION_TYPE:turnaround_finger_roll_shot',
#        'ACTION_TYPE:turnaround_hook_shot',
#        'ACTION_TYPE:turnaround_jump_shot', 'SEASON_GAME_NUMBER',
#        'CAREER_GAME_NUMBER'], dtype=object)

# %% [markdown]
# ---
#
# ### 3.  Prepare the dataset for training AND validation
#
# - Make predictor matrix `X` and target variable `y`
# - Split your data into a validation set using `train_test_split`

# %%
# A:
#target = kobe['SHOTS_MADE']
#X = kobe.drop('SHOTS_MADE', axis = 1)

# %%
X = kobe.drop("SHOTS_MADE", axis = 1)
y = kobe["SHOTS_MADE"]

# %%
X.shape[0] == y.shape[0]
# Out:
# True

# %% [markdown]
# ---
#
# ### 4. Build a linear regression predicting `SHOTS_MADE` from the rest of the columns.
#
# 1. How does it perform? Keep the regression metrics we talked about on Tuesday in mind, like mean squared error, mean absolute error, and $R^2$
# 2. Is there a disparity between your train set and your test set? What does that indicate?

# %%
train_test_split(X,y,test_size=0.3)

# %%
# A: # Training/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25)

lm = LinearRegression()

#X = df 
#y = target 

model = lm.fit(X_train, y_train)
prediction = model.predict (X_test)
score = model.score (X_test, y_test)
print score
# Out:
# -5.72950652745e+16

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
kobe.corr()
# Out:
#                                                 SHOTS_MADE  AWAY_GAME  \
# SHOTS_MADE                                        1.000000   0.009671
# AWAY_GAME                                         0.009671   1.000000
# SEASON_OPPONENT:atl:1996-97                      -0.076029  -0.000046
# SEASON_OPPONENT:atl:1997-98                      -0.024370  -0.000046
# SEASON_OPPONENT:atl:1999-00                       0.004683   0.025310
# SEASON_OPPONENT:atl:2000-01                       0.004683   0.025310
# SEASON_OPPONENT:atl:2001-02                       0.011791  -0.000046
# SEASON_OPPONENT:atl:2002-03                       0.006625  -0.000046
# SEASON_OPPONENT:atl:2003-04                       0.011986  -0.025375
# SEASON_OPPONENT:atl:2004-05                      -0.017227  -0.025375
# SEASON_OPPONENT:atl:2005-06                       0.027288  -0.000046
# SEASON_OPPONENT:atl:2006-07                       0.011986   0.025310
# SEASON_OPPONENT:atl:2007-08                      -0.014039  -0.000046
# SEASON_OPPONENT:atl:2008-09                      -0.029536  -0.000046
# SEASON_OPPONENT:atl:2009-10                       0.047952  -0.000046
# SEASON_OPPONENT:atl:2010-11                      -0.024370  -0.000046
# SEASON_OPPONENT:atl:2011-12                      -0.017227  -0.025375
# SEASON_OPPONENT:atl:2012-13                       0.037620  -0.000046
# SEASON_OPPONENT:atl:2013-14                      -0.031833   0.025310
# SEASON_OPPONENT:atl:2014-15                       0.011986   0.025310
# SEASON_OPPONENT:atl:2015-16                      -0.039137   0.025310
# SEASON_OPPONENT:bkn:2012-13                      -0.003707  -0.000046
# SEASON_OPPONENT:bkn:2015-16                      -0.024530   0.025310
# SEASON_OPPONENT:bos:1996-97                      -0.046440   0.025310
# SEASON_OPPONENT:bos:1997-98                      -0.029536  -0.000046
# SEASON_OPPONENT:bos:1999-00                       0.001459  -0.000046
# SEASON_OPPONENT:bos:2001-02                      -0.008873  -0.000046
# SEASON_OPPONENT:bos:2002-03                      -0.008873  -0.000046
# SEASON_OPPONENT:bos:2003-04                      -0.034702  -0.000046
# SEASON_OPPONENT:bos:2004-05                      -0.008873  -0.000046
# ...                                                    ...        ...
# ACTION_TYPE:pullup_jump_shot                     -0.010251   0.073922
# ACTION_TYPE:putback_dunk_shot                     0.010643  -0.015701
# ACTION_TYPE:putback_layup_shot                    0.042252   0.031654
# ACTION_TYPE:putback_slam_dunk_shot                0.026593   0.025310
# ACTION_TYPE:reverse_dunk_shot                     0.096487  -0.033163
# ACTION_TYPE:reverse_layup_shot                    0.090860  -0.005726
# ACTION_TYPE:reverse_slam_dunk_shot               -0.005456  -0.038752
# ACTION_TYPE:running_bank_shot                     0.022524   0.036776
# ACTION_TYPE:running_dunk_shot                     0.020998   0.006001
# ACTION_TYPE:running_finger_roll_layup_shot        0.043730  -0.032543
# ACTION_TYPE:running_finger_roll_shot             -0.015848  -0.029419
# ACTION_TYPE:running_hook_shot                     0.060952  -0.006826
# ACTION_TYPE:running_jump_shot                    -0.015739  -0.109178
# ACTION_TYPE:running_layup_shot                    0.030503  -0.035188
# ACTION_TYPE:running_pull-up_jump_shot            -0.006567  -0.019153
# ACTION_TYPE:running_reverse_layup_shot           -0.008448  -0.034018
# ACTION_TYPE:running_slam_dunk_shot               -0.009924  -0.025375
# ACTION_TYPE:running_tip_shot                     -0.017077  -0.033903
# ACTION_TYPE:slam_dunk_shot                       -0.042799  -0.163374
# ACTION_TYPE:step_back_jump_shot                   0.019709   0.063947
# ACTION_TYPE:tip_layup_shot                       -0.014039  -0.000046
# ACTION_TYPE:tip_shot                             -0.036108  -0.021380
# ACTION_TYPE:turnaround_bank_shot                  0.062609   0.011718
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot   -0.017227   0.025310
# ACTION_TYPE:turnaround_fadeaway_shot              0.006544   0.014764
# ACTION_TYPE:turnaround_finger_roll_shot           0.000266   0.002704
# ACTION_TYPE:turnaround_hook_shot                 -0.016149   0.024190
# ACTION_TYPE:turnaround_jump_shot                  0.146655   0.053858
# SEASON_GAME_NUMBER                                0.059012   0.022408
# CAREER_GAME_NUMBER                                0.194842   0.007128
#
#                                                 SEASON_OPPONENT:atl:1996-97  \
# SHOTS_MADE                                                        -0.076029
# AWAY_GAME                                                         -0.000046
# SEASON_OPPONENT:atl:1996-97                                        1.000000
# SEASON_OPPONENT:atl:1997-98                                       -0.001285
# SEASON_OPPONENT:atl:1999-00                                       -0.000909
# SEASON_OPPONENT:atl:2000-01                                       -0.000909
# SEASON_OPPONENT:atl:2001-02                                       -0.001285
# SEASON_OPPONENT:atl:2002-03                                       -0.001285
# SEASON_OPPONENT:atl:2003-04                                       -0.000909
# SEASON_OPPONENT:atl:2004-05                                       -0.000909
# SEASON_OPPONENT:atl:2005-06                                       -0.001285
# SEASON_OPPONENT:atl:2006-07                                       -0.000909
# SEASON_OPPONENT:atl:2007-08                                       -0.001285
# SEASON_OPPONENT:atl:2008-09                                       -0.001285
# SEASON_OPPONENT:atl:2009-10                                       -0.001285
# SEASON_OPPONENT:atl:2010-11                                       -0.001285
# SEASON_OPPONENT:atl:2011-12                                       -0.000909
# SEASON_OPPONENT:atl:2012-13                                       -0.001285
# SEASON_OPPONENT:atl:2013-14                                       -0.000909
# SEASON_OPPONENT:atl:2014-15                                       -0.000909
# SEASON_OPPONENT:atl:2015-16                                       -0.000909
# SEASON_OPPONENT:bkn:2012-13                                       -0.001285
# SEASON_OPPONENT:bkn:2015-16                                       -0.000909
# SEASON_OPPONENT:bos:1996-97                                       -0.000909
# SEASON_OPPONENT:bos:1997-98                                       -0.001285
# SEASON_OPPONENT:bos:1999-00                                       -0.001285
# SEASON_OPPONENT:bos:2001-02                                       -0.001285
# SEASON_OPPONENT:bos:2002-03                                       -0.001285
# SEASON_OPPONENT:bos:2003-04                                       -0.001285
# SEASON_OPPONENT:bos:2004-05                                       -0.001285
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.011757
# ACTION_TYPE:putback_dunk_shot                                     -0.001980
# ACTION_TYPE:putback_layup_shot                                    -0.003494
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000909
# ACTION_TYPE:reverse_dunk_shot                                     -0.007534
# ACTION_TYPE:reverse_layup_shot                                    -0.016049
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.003473
# ACTION_TYPE:running_bank_shot                                     -0.005772
# ACTION_TYPE:running_dunk_shot                                     -0.003872
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.002189
# ACTION_TYPE:running_finger_roll_shot                              -0.001771
# ACTION_TYPE:running_hook_shot                                     -0.005417
# ACTION_TYPE:running_jump_shot                                     -0.021371
# ACTION_TYPE:running_layup_shot                                    -0.006716
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001546
# ACTION_TYPE:running_reverse_layup_shot                            -0.002252
# ACTION_TYPE:running_slam_dunk_shot                                -0.000909
# ACTION_TYPE:running_tip_shot                                      -0.001214
# ACTION_TYPE:slam_dunk_shot                                        -0.014776
# ACTION_TYPE:step_back_jump_shot                                   -0.008567
# ACTION_TYPE:tip_layup_shot                                        -0.001285
# ACTION_TYPE:tip_shot                                              -0.010103
# ACTION_TYPE:turnaround_bank_shot                                  -0.006594
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000909
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.012282
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.001282
# ACTION_TYPE:turnaround_hook_shot                                  -0.003170
# ACTION_TYPE:turnaround_jump_shot                                  -0.023060
# SEASON_GAME_NUMBER                                                -0.024709
# CAREER_GAME_NUMBER                                                -0.060220
#
#                                                 SEASON_OPPONENT:atl:1997-98  \
# SHOTS_MADE                                                        -0.024370
# AWAY_GAME                                                         -0.000046
# SEASON_OPPONENT:atl:1996-97                                       -0.001285
# SEASON_OPPONENT:atl:1997-98                                        1.000000
# SEASON_OPPONENT:atl:1999-00                                       -0.000909
# SEASON_OPPONENT:atl:2000-01                                       -0.000909
# SEASON_OPPONENT:atl:2001-02                                       -0.001285
# SEASON_OPPONENT:atl:2002-03                                       -0.001285
# SEASON_OPPONENT:atl:2003-04                                       -0.000909
# SEASON_OPPONENT:atl:2004-05                                       -0.000909
# SEASON_OPPONENT:atl:2005-06                                       -0.001285
# SEASON_OPPONENT:atl:2006-07                                       -0.000909
# SEASON_OPPONENT:atl:2007-08                                       -0.001285
# SEASON_OPPONENT:atl:2008-09                                       -0.001285
# SEASON_OPPONENT:atl:2009-10                                       -0.001285
# SEASON_OPPONENT:atl:2010-11                                       -0.001285
# SEASON_OPPONENT:atl:2011-12                                       -0.000909
# SEASON_OPPONENT:atl:2012-13                                       -0.001285
# SEASON_OPPONENT:atl:2013-14                                       -0.000909
# SEASON_OPPONENT:atl:2014-15                                       -0.000909
# SEASON_OPPONENT:atl:2015-16                                       -0.000909
# SEASON_OPPONENT:bkn:2012-13                                       -0.001285
# SEASON_OPPONENT:bkn:2015-16                                       -0.000909
# SEASON_OPPONENT:bos:1996-97                                       -0.000909
# SEASON_OPPONENT:bos:1997-98                                       -0.001285
# SEASON_OPPONENT:bos:1999-00                                       -0.001285
# SEASON_OPPONENT:bos:2001-02                                       -0.001285
# SEASON_OPPONENT:bos:2002-03                                       -0.001285
# SEASON_OPPONENT:bos:2003-04                                       -0.001285
# SEASON_OPPONENT:bos:2004-05                                       -0.001285
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.011757
# ACTION_TYPE:putback_dunk_shot                                     -0.001980
# ACTION_TYPE:putback_layup_shot                                    -0.003494
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000909
# ACTION_TYPE:reverse_dunk_shot                                     -0.007534
# ACTION_TYPE:reverse_layup_shot                                    -0.016049
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.003473
# ACTION_TYPE:running_bank_shot                                     -0.005772
# ACTION_TYPE:running_dunk_shot                                     -0.003872
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.002189
# ACTION_TYPE:running_finger_roll_shot                              -0.001771
# ACTION_TYPE:running_hook_shot                                     -0.005417
# ACTION_TYPE:running_jump_shot                                      0.063994
# ACTION_TYPE:running_layup_shot                                    -0.006716
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001546
# ACTION_TYPE:running_reverse_layup_shot                            -0.002252
# ACTION_TYPE:running_slam_dunk_shot                                -0.000909
# ACTION_TYPE:running_tip_shot                                      -0.001214
# ACTION_TYPE:slam_dunk_shot                                        -0.014776
# ACTION_TYPE:step_back_jump_shot                                   -0.008567
# ACTION_TYPE:tip_layup_shot                                        -0.001285
# ACTION_TYPE:tip_shot                                              -0.010103
# ACTION_TYPE:turnaround_bank_shot                                  -0.006594
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000909
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.012282
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.001282
# ACTION_TYPE:turnaround_hook_shot                                  -0.003170
# ACTION_TYPE:turnaround_jump_shot                                  -0.023060
# SEASON_GAME_NUMBER                                                -0.024709
# CAREER_GAME_NUMBER                                                -0.054241
#
#                                                 SEASON_OPPONENT:atl:1999-00  \
# SHOTS_MADE                                                         0.004683
# AWAY_GAME                                                          0.025310
# SEASON_OPPONENT:atl:1996-97                                       -0.000909
# SEASON_OPPONENT:atl:1997-98                                       -0.000909
# SEASON_OPPONENT:atl:1999-00                                        1.000000
# SEASON_OPPONENT:atl:2000-01                                       -0.000642
# SEASON_OPPONENT:atl:2001-02                                       -0.000909
# SEASON_OPPONENT:atl:2002-03                                       -0.000909
# SEASON_OPPONENT:atl:2003-04                                       -0.000642
# SEASON_OPPONENT:atl:2004-05                                       -0.000642
# SEASON_OPPONENT:atl:2005-06                                       -0.000909
# SEASON_OPPONENT:atl:2006-07                                       -0.000642
# SEASON_OPPONENT:atl:2007-08                                       -0.000909
# SEASON_OPPONENT:atl:2008-09                                       -0.000909
# SEASON_OPPONENT:atl:2009-10                                       -0.000909
# SEASON_OPPONENT:atl:2010-11                                       -0.000909
# SEASON_OPPONENT:atl:2011-12                                       -0.000642
# SEASON_OPPONENT:atl:2012-13                                       -0.000909
# SEASON_OPPONENT:atl:2013-14                                       -0.000642
# SEASON_OPPONENT:atl:2014-15                                       -0.000642
# SEASON_OPPONENT:atl:2015-16                                       -0.000642
# SEASON_OPPONENT:bkn:2012-13                                       -0.000909
# SEASON_OPPONENT:bkn:2015-16                                       -0.000642
# SEASON_OPPONENT:bos:1996-97                                       -0.000642
# SEASON_OPPONENT:bos:1997-98                                       -0.000909
# SEASON_OPPONENT:bos:1999-00                                       -0.000909
# SEASON_OPPONENT:bos:2001-02                                       -0.000909
# SEASON_OPPONENT:bos:2002-03                                       -0.000909
# SEASON_OPPONENT:bos:2003-04                                       -0.000909
# SEASON_OPPONENT:bos:2004-05                                       -0.000909
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.008310
# ACTION_TYPE:putback_dunk_shot                                     -0.001400
# ACTION_TYPE:putback_layup_shot                                    -0.002470
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000642
# ACTION_TYPE:reverse_dunk_shot                                     -0.005326
# ACTION_TYPE:reverse_layup_shot                                    -0.011345
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.002455
# ACTION_TYPE:running_bank_shot                                     -0.004080
# ACTION_TYPE:running_dunk_shot                                     -0.002737
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.001547
# ACTION_TYPE:running_finger_roll_shot                              -0.001252
# ACTION_TYPE:running_hook_shot                                     -0.003829
# ACTION_TYPE:running_jump_shot                                     -0.015106
# ACTION_TYPE:running_layup_shot                                    -0.004747
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001093
# ACTION_TYPE:running_reverse_layup_shot                            -0.001592
# ACTION_TYPE:running_slam_dunk_shot                                -0.000642
# ACTION_TYPE:running_tip_shot                                      -0.000858
# ACTION_TYPE:slam_dunk_shot                                        -0.010445
# ACTION_TYPE:step_back_jump_shot                                   -0.006056
# ACTION_TYPE:tip_layup_shot                                        -0.000909
# ACTION_TYPE:tip_shot                                              -0.007142
# ACTION_TYPE:turnaround_bank_shot                                  -0.004661
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000642
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.008682
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.000906
# ACTION_TYPE:turnaround_hook_shot                                  -0.002241
# ACTION_TYPE:turnaround_jump_shot                                  -0.016301
# SEASON_GAME_NUMBER                                                -0.033038
# CAREER_GAME_NUMBER                                                -0.030961
#
#                                                 SEASON_OPPONENT:atl:2000-01  \
# SHOTS_MADE                                                         0.004683
# AWAY_GAME                                                          0.025310
# SEASON_OPPONENT:atl:1996-97                                       -0.000909
# SEASON_OPPONENT:atl:1997-98                                       -0.000909
# SEASON_OPPONENT:atl:1999-00                                       -0.000642
# SEASON_OPPONENT:atl:2000-01                                        1.000000
# SEASON_OPPONENT:atl:2001-02                                       -0.000909
# SEASON_OPPONENT:atl:2002-03                                       -0.000909
# SEASON_OPPONENT:atl:2003-04                                       -0.000642
# SEASON_OPPONENT:atl:2004-05                                       -0.000642
# SEASON_OPPONENT:atl:2005-06                                       -0.000909
# SEASON_OPPONENT:atl:2006-07                                       -0.000642
# SEASON_OPPONENT:atl:2007-08                                       -0.000909
# SEASON_OPPONENT:atl:2008-09                                       -0.000909
# SEASON_OPPONENT:atl:2009-10                                       -0.000909
# SEASON_OPPONENT:atl:2010-11                                       -0.000909
# SEASON_OPPONENT:atl:2011-12                                       -0.000642
# SEASON_OPPONENT:atl:2012-13                                       -0.000909
# SEASON_OPPONENT:atl:2013-14                                       -0.000642
# SEASON_OPPONENT:atl:2014-15                                       -0.000642
# SEASON_OPPONENT:atl:2015-16                                       -0.000642
# SEASON_OPPONENT:bkn:2012-13                                       -0.000909
# SEASON_OPPONENT:bkn:2015-16                                       -0.000642
# SEASON_OPPONENT:bos:1996-97                                       -0.000642
# SEASON_OPPONENT:bos:1997-98                                       -0.000909
# SEASON_OPPONENT:bos:1999-00                                       -0.000909
# SEASON_OPPONENT:bos:2001-02                                       -0.000909
# SEASON_OPPONENT:bos:2002-03                                       -0.000909
# SEASON_OPPONENT:bos:2003-04                                       -0.000909
# SEASON_OPPONENT:bos:2004-05                                       -0.000909
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.008310
# ACTION_TYPE:putback_dunk_shot                                     -0.001400
# ACTION_TYPE:putback_layup_shot                                    -0.002470
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000642
# ACTION_TYPE:reverse_dunk_shot                                     -0.005326
# ACTION_TYPE:reverse_layup_shot                                    -0.011345
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.002455
# ACTION_TYPE:running_bank_shot                                     -0.004080
# ACTION_TYPE:running_dunk_shot                                      0.209408
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.001547
# ACTION_TYPE:running_finger_roll_shot                              -0.001252
# ACTION_TYPE:running_hook_shot                                     -0.003829
# ACTION_TYPE:running_jump_shot                                     -0.015106
# ACTION_TYPE:running_layup_shot                                    -0.004747
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001093
# ACTION_TYPE:running_reverse_layup_shot                            -0.001592
# ACTION_TYPE:running_slam_dunk_shot                                -0.000642
# ACTION_TYPE:running_tip_shot                                      -0.000858
# ACTION_TYPE:slam_dunk_shot                                        -0.010445
# ACTION_TYPE:step_back_jump_shot                                   -0.006056
# ACTION_TYPE:tip_layup_shot                                        -0.000909
# ACTION_TYPE:tip_shot                                              -0.007142
# ACTION_TYPE:turnaround_bank_shot                                  -0.004661
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000642
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.008682
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.000906
# ACTION_TYPE:turnaround_hook_shot                                  -0.002241
# ACTION_TYPE:turnaround_jump_shot                                  -0.016301
# SEASON_GAME_NUMBER                                                 0.018543
# CAREER_GAME_NUMBER                                                -0.023016
#
#                                                 SEASON_OPPONENT:atl:2001-02  \
# SHOTS_MADE                                                         0.011791
# AWAY_GAME                                                         -0.000046
# SEASON_OPPONENT:atl:1996-97                                       -0.001285
# SEASON_OPPONENT:atl:1997-98                                       -0.001285
# SEASON_OPPONENT:atl:1999-00                                       -0.000909
# SEASON_OPPONENT:atl:2000-01                                       -0.000909
# SEASON_OPPONENT:atl:2001-02                                        1.000000
# SEASON_OPPONENT:atl:2002-03                                       -0.001285
# SEASON_OPPONENT:atl:2003-04                                       -0.000909
# SEASON_OPPONENT:atl:2004-05                                       -0.000909
# SEASON_OPPONENT:atl:2005-06                                       -0.001285
# SEASON_OPPONENT:atl:2006-07                                       -0.000909
# SEASON_OPPONENT:atl:2007-08                                       -0.001285
# SEASON_OPPONENT:atl:2008-09                                       -0.001285
# SEASON_OPPONENT:atl:2009-10                                       -0.001285
# SEASON_OPPONENT:atl:2010-11                                       -0.001285
# SEASON_OPPONENT:atl:2011-12                                       -0.000909
# SEASON_OPPONENT:atl:2012-13                                       -0.001285
# SEASON_OPPONENT:atl:2013-14                                       -0.000909
# SEASON_OPPONENT:atl:2014-15                                       -0.000909
# SEASON_OPPONENT:atl:2015-16                                       -0.000909
# SEASON_OPPONENT:bkn:2012-13                                       -0.001285
# SEASON_OPPONENT:bkn:2015-16                                       -0.000909
# SEASON_OPPONENT:bos:1996-97                                       -0.000909
# SEASON_OPPONENT:bos:1997-98                                       -0.001285
# SEASON_OPPONENT:bos:1999-00                                       -0.001285
# SEASON_OPPONENT:bos:2001-02                                       -0.001285
# SEASON_OPPONENT:bos:2002-03                                       -0.001285
# SEASON_OPPONENT:bos:2003-04                                       -0.001285
# SEASON_OPPONENT:bos:2004-05                                       -0.001285
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.011757
# ACTION_TYPE:putback_dunk_shot                                     -0.001980
# ACTION_TYPE:putback_layup_shot                                    -0.003494
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000909
# ACTION_TYPE:reverse_dunk_shot                                     -0.007534
# ACTION_TYPE:reverse_layup_shot                                     0.134629
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.003473
# ACTION_TYPE:running_bank_shot                                     -0.005772
# ACTION_TYPE:running_dunk_shot                                     -0.003872
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.002189
# ACTION_TYPE:running_finger_roll_shot                              -0.001771
# ACTION_TYPE:running_hook_shot                                     -0.005417
# ACTION_TYPE:running_jump_shot                                      0.004895
# ACTION_TYPE:running_layup_shot                                    -0.006716
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001546
# ACTION_TYPE:running_reverse_layup_shot                            -0.002252
# ACTION_TYPE:running_slam_dunk_shot                                -0.000909
# ACTION_TYPE:running_tip_shot                                      -0.001214
# ACTION_TYPE:slam_dunk_shot                                        -0.014776
# ACTION_TYPE:step_back_jump_shot                                   -0.008567
# ACTION_TYPE:tip_layup_shot                                        -0.001285
# ACTION_TYPE:tip_shot                                              -0.010103
# ACTION_TYPE:turnaround_bank_shot                                  -0.006594
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000909
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.012282
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.001282
# ACTION_TYPE:turnaround_hook_shot                                  -0.003170
# ACTION_TYPE:turnaround_jump_shot                                  -0.023060
# SEASON_GAME_NUMBER                                                 0.003515
# CAREER_GAME_NUMBER                                                -0.027180
#
#                                                 SEASON_OPPONENT:atl:2002-03  \
# SHOTS_MADE                                                         0.006625
# AWAY_GAME                                                         -0.000046
# SEASON_OPPONENT:atl:1996-97                                       -0.001285
# SEASON_OPPONENT:atl:1997-98                                       -0.001285
# SEASON_OPPONENT:atl:1999-00                                       -0.000909
# SEASON_OPPONENT:atl:2000-01                                       -0.000909
# SEASON_OPPONENT:atl:2001-02                                       -0.001285
# SEASON_OPPONENT:atl:2002-03                                        1.000000
# SEASON_OPPONENT:atl:2003-04                                       -0.000909
# SEASON_OPPONENT:atl:2004-05                                       -0.000909
# SEASON_OPPONENT:atl:2005-06                                       -0.001285
# SEASON_OPPONENT:atl:2006-07                                       -0.000909
# SEASON_OPPONENT:atl:2007-08                                       -0.001285
# SEASON_OPPONENT:atl:2008-09                                       -0.001285
# SEASON_OPPONENT:atl:2009-10                                       -0.001285
# SEASON_OPPONENT:atl:2010-11                                       -0.001285
# SEASON_OPPONENT:atl:2011-12                                       -0.000909
# SEASON_OPPONENT:atl:2012-13                                       -0.001285
# SEASON_OPPONENT:atl:2013-14                                       -0.000909
# SEASON_OPPONENT:atl:2014-15                                       -0.000909
# SEASON_OPPONENT:atl:2015-16                                       -0.000909
# SEASON_OPPONENT:bkn:2012-13                                       -0.001285
# SEASON_OPPONENT:bkn:2015-16                                       -0.000909
# SEASON_OPPONENT:bos:1996-97                                       -0.000909
# SEASON_OPPONENT:bos:1997-98                                       -0.001285
# SEASON_OPPONENT:bos:1999-00                                       -0.001285
# SEASON_OPPONENT:bos:2001-02                                       -0.001285
# SEASON_OPPONENT:bos:2002-03                                       -0.001285
# SEASON_OPPONENT:bos:2003-04                                       -0.001285
# SEASON_OPPONENT:bos:2004-05                                       -0.001285
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.011757
# ACTION_TYPE:putback_dunk_shot                                     -0.001980
# ACTION_TYPE:putback_layup_shot                                    -0.003494
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000909
# ACTION_TYPE:reverse_dunk_shot                                     -0.007534
# ACTION_TYPE:reverse_layup_shot                                    -0.016049
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.003473
# ACTION_TYPE:running_bank_shot                                     -0.005772
# ACTION_TYPE:running_dunk_shot                                     -0.003872
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.002189
# ACTION_TYPE:running_finger_roll_shot                              -0.001771
# ACTION_TYPE:running_hook_shot                                     -0.005417
# ACTION_TYPE:running_jump_shot                                     -0.005850
# ACTION_TYPE:running_layup_shot                                    -0.006716
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001546
# ACTION_TYPE:running_reverse_layup_shot                            -0.002252
# ACTION_TYPE:running_slam_dunk_shot                                -0.000909
# ACTION_TYPE:running_tip_shot                                      -0.001214
# ACTION_TYPE:slam_dunk_shot                                         0.007334
# ACTION_TYPE:step_back_jump_shot                                   -0.008567
# ACTION_TYPE:tip_layup_shot                                        -0.001285
# ACTION_TYPE:tip_shot                                              -0.010103
# ACTION_TYPE:turnaround_bank_shot                                  -0.006594
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000909
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.012282
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.001282
# ACTION_TYPE:turnaround_hook_shot                                  -0.003170
# ACTION_TYPE:turnaround_jump_shot                                  -0.005776
# SEASON_GAME_NUMBER                                                -0.005434
# CAREER_GAME_NUMBER                                                -0.019807
#
#                                                 SEASON_OPPONENT:atl:2003-04  \
# SHOTS_MADE                                                         0.011986
# AWAY_GAME                                                         -0.025375
# SEASON_OPPONENT:atl:1996-97                                       -0.000909
# SEASON_OPPONENT:atl:1997-98                                       -0.000909
# SEASON_OPPONENT:atl:1999-00                                       -0.000642
# SEASON_OPPONENT:atl:2000-01                                       -0.000642
# SEASON_OPPONENT:atl:2001-02                                       -0.000909
# SEASON_OPPONENT:atl:2002-03                                       -0.000909
# SEASON_OPPONENT:atl:2003-04                                        1.000000
# SEASON_OPPONENT:atl:2004-05                                       -0.000642
# SEASON_OPPONENT:atl:2005-06                                       -0.000909
# SEASON_OPPONENT:atl:2006-07                                       -0.000642
# SEASON_OPPONENT:atl:2007-08                                       -0.000909
# SEASON_OPPONENT:atl:2008-09                                       -0.000909
# SEASON_OPPONENT:atl:2009-10                                       -0.000909
# SEASON_OPPONENT:atl:2010-11                                       -0.000909
# SEASON_OPPONENT:atl:2011-12                                       -0.000642
# SEASON_OPPONENT:atl:2012-13                                       -0.000909
# SEASON_OPPONENT:atl:2013-14                                       -0.000642
# SEASON_OPPONENT:atl:2014-15                                       -0.000642
# SEASON_OPPONENT:atl:2015-16                                       -0.000642
# SEASON_OPPONENT:bkn:2012-13                                       -0.000909
# SEASON_OPPONENT:bkn:2015-16                                       -0.000642
# SEASON_OPPONENT:bos:1996-97                                       -0.000642
# SEASON_OPPONENT:bos:1997-98                                       -0.000909
# SEASON_OPPONENT:bos:1999-00                                       -0.000909
# SEASON_OPPONENT:bos:2001-02                                       -0.000909
# SEASON_OPPONENT:bos:2002-03                                       -0.000909
# SEASON_OPPONENT:bos:2003-04                                       -0.000909
# SEASON_OPPONENT:bos:2004-05                                       -0.000909
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.008310
# ACTION_TYPE:putback_dunk_shot                                     -0.001400
# ACTION_TYPE:putback_layup_shot                                    -0.002470
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000642
# ACTION_TYPE:reverse_dunk_shot                                     -0.005326
# ACTION_TYPE:reverse_layup_shot                                     0.038063
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.002455
# ACTION_TYPE:running_bank_shot                                     -0.004080
# ACTION_TYPE:running_dunk_shot                                     -0.002737
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.001547
# ACTION_TYPE:running_finger_roll_shot                              -0.001252
# ACTION_TYPE:running_hook_shot                                     -0.003829
# ACTION_TYPE:running_jump_shot                                     -0.015106
# ACTION_TYPE:running_layup_shot                                    -0.004747
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001093
# ACTION_TYPE:running_reverse_layup_shot                            -0.001592
# ACTION_TYPE:running_slam_dunk_shot                                -0.000642
# ACTION_TYPE:running_tip_shot                                      -0.000858
# ACTION_TYPE:slam_dunk_shot                                         0.025749
# ACTION_TYPE:step_back_jump_shot                                   -0.006056
# ACTION_TYPE:tip_layup_shot                                        -0.000909
# ACTION_TYPE:tip_shot                                              -0.007142
# ACTION_TYPE:turnaround_bank_shot                                  -0.004661
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000642
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.008682
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.000906
# ACTION_TYPE:turnaround_hook_shot                                  -0.002241
# ACTION_TYPE:turnaround_jump_shot                                   0.037716
# SEASON_GAME_NUMBER                                                -0.010654
# CAREER_GAME_NUMBER                                                -0.009099
#
#                                                 SEASON_OPPONENT:atl:2004-05  \
# SHOTS_MADE                                                        -0.017227
# AWAY_GAME                                                         -0.025375
# SEASON_OPPONENT:atl:1996-97                                       -0.000909
# SEASON_OPPONENT:atl:1997-98                                       -0.000909
# SEASON_OPPONENT:atl:1999-00                                       -0.000642
# SEASON_OPPONENT:atl:2000-01                                       -0.000642
# SEASON_OPPONENT:atl:2001-02                                       -0.000909
# SEASON_OPPONENT:atl:2002-03                                       -0.000909
# SEASON_OPPONENT:atl:2003-04                                       -0.000642
# SEASON_OPPONENT:atl:2004-05                                        1.000000
# SEASON_OPPONENT:atl:2005-06                                       -0.000909
# SEASON_OPPONENT:atl:2006-07                                       -0.000642
# SEASON_OPPONENT:atl:2007-08                                       -0.000909
# SEASON_OPPONENT:atl:2008-09                                       -0.000909
# SEASON_OPPONENT:atl:2009-10                                       -0.000909
# SEASON_OPPONENT:atl:2010-11                                       -0.000909
# SEASON_OPPONENT:atl:2011-12                                       -0.000642
# SEASON_OPPONENT:atl:2012-13                                       -0.000909
# SEASON_OPPONENT:atl:2013-14                                       -0.000642
# SEASON_OPPONENT:atl:2014-15                                       -0.000642
# SEASON_OPPONENT:atl:2015-16                                       -0.000642
# SEASON_OPPONENT:bkn:2012-13                                       -0.000909
# SEASON_OPPONENT:bkn:2015-16                                       -0.000642
# SEASON_OPPONENT:bos:1996-97                                       -0.000642
# SEASON_OPPONENT:bos:1997-98                                       -0.000909
# SEASON_OPPONENT:bos:1999-00                                       -0.000909
# SEASON_OPPONENT:bos:2001-02                                       -0.000909
# SEASON_OPPONENT:bos:2002-03                                       -0.000909
# SEASON_OPPONENT:bos:2003-04                                       -0.000909
# SEASON_OPPONENT:bos:2004-05                                       -0.000909
# ...                                                                     ...
# ACTION_TYPE:pullup_jump_shot                                      -0.008310
# ACTION_TYPE:putback_dunk_shot                                     -0.001400
# ACTION_TYPE:putback_layup_shot                                    -0.002470
# ACTION_TYPE:putback_slam_dunk_shot                                -0.000642
# ACTION_TYPE:reverse_dunk_shot                                     -0.005326
# ACTION_TYPE:reverse_layup_shot                                     0.066884
# ACTION_TYPE:reverse_slam_dunk_shot                                -0.002455
# ACTION_TYPE:running_bank_shot                                     -0.004080
# ACTION_TYPE:running_dunk_shot                                     -0.002737
# ACTION_TYPE:running_finger_roll_layup_shot                        -0.001547
# ACTION_TYPE:running_finger_roll_shot                              -0.001252
# ACTION_TYPE:running_hook_shot                                     -0.003829
# ACTION_TYPE:running_jump_shot                                     -0.015106
# ACTION_TYPE:running_layup_shot                                    -0.004747
# ACTION_TYPE:running_pull-up_jump_shot                             -0.001093
# ACTION_TYPE:running_reverse_layup_shot                            -0.001592
# ACTION_TYPE:running_slam_dunk_shot                                -0.000642
# ACTION_TYPE:running_tip_shot                                      -0.000858
# ACTION_TYPE:slam_dunk_shot                                        -0.010445
# ACTION_TYPE:step_back_jump_shot                                   -0.006056
# ACTION_TYPE:tip_layup_shot                                        -0.000909
# ACTION_TYPE:tip_shot                                              -0.007142
# ACTION_TYPE:turnaround_bank_shot                                  -0.004661
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                    -0.000642
# ACTION_TYPE:turnaround_fadeaway_shot                              -0.008682
# ACTION_TYPE:turnaround_finger_roll_shot                           -0.000906
# ACTION_TYPE:turnaround_hook_shot                                  -0.002241
# ACTION_TYPE:turnaround_jump_shot                                  -0.016301
# SEASON_GAME_NUMBER                                                -0.037904
# CAREER_GAME_NUMBER                                                -0.005831
#
#                                                        ...          \
# SHOTS_MADE                                             ...
# AWAY_GAME                                              ...
# SEASON_OPPONENT:atl:1996-97                            ...
# SEASON_OPPONENT:atl:1997-98                            ...
# SEASON_OPPONENT:atl:1999-00                            ...
# SEASON_OPPONENT:atl:2000-01                            ...
# SEASON_OPPONENT:atl:2001-02                            ...
# SEASON_OPPONENT:atl:2002-03                            ...
# SEASON_OPPONENT:atl:2003-04                            ...
# SEASON_OPPONENT:atl:2004-05                            ...
# SEASON_OPPONENT:atl:2005-06                            ...
# SEASON_OPPONENT:atl:2006-07                            ...
# SEASON_OPPONENT:atl:2007-08                            ...
# SEASON_OPPONENT:atl:2008-09                            ...
# SEASON_OPPONENT:atl:2009-10                            ...
# SEASON_OPPONENT:atl:2010-11                            ...
# SEASON_OPPONENT:atl:2011-12                            ...
# SEASON_OPPONENT:atl:2012-13                            ...
# SEASON_OPPONENT:atl:2013-14                            ...
# SEASON_OPPONENT:atl:2014-15                            ...
# SEASON_OPPONENT:atl:2015-16                            ...
# SEASON_OPPONENT:bkn:2012-13                            ...
# SEASON_OPPONENT:bkn:2015-16                            ...
# SEASON_OPPONENT:bos:1996-97                            ...
# SEASON_OPPONENT:bos:1997-98                            ...
# SEASON_OPPONENT:bos:1999-00                            ...
# SEASON_OPPONENT:bos:2001-02                            ...
# SEASON_OPPONENT:bos:2002-03                            ...
# SEASON_OPPONENT:bos:2003-04                            ...
# SEASON_OPPONENT:bos:2004-05                            ...
# ...                                                    ...
# ACTION_TYPE:pullup_jump_shot                           ...
# ACTION_TYPE:putback_dunk_shot                          ...
# ACTION_TYPE:putback_layup_shot                         ...
# ACTION_TYPE:putback_slam_dunk_shot                     ...
# ACTION_TYPE:reverse_dunk_shot                          ...
# ACTION_TYPE:reverse_layup_shot                         ...
# ACTION_TYPE:reverse_slam_dunk_shot                     ...
# ACTION_TYPE:running_bank_shot                          ...
# ACTION_TYPE:running_dunk_shot                          ...
# ACTION_TYPE:running_finger_roll_layup_shot             ...
# ACTION_TYPE:running_finger_roll_shot                   ...
# ACTION_TYPE:running_hook_shot                          ...
# ACTION_TYPE:running_jump_shot                          ...
# ACTION_TYPE:running_layup_shot                         ...
# ACTION_TYPE:running_pull-up_jump_shot                  ...
# ACTION_TYPE:running_reverse_layup_shot                 ...
# ACTION_TYPE:running_slam_dunk_shot                     ...
# ACTION_TYPE:running_tip_shot                           ...
# ACTION_TYPE:slam_dunk_shot                             ...
# ACTION_TYPE:step_back_jump_shot                        ...
# ACTION_TYPE:tip_layup_shot                             ...
# ACTION_TYPE:tip_shot                                   ...
# ACTION_TYPE:turnaround_bank_shot                       ...
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot         ...
# ACTION_TYPE:turnaround_fadeaway_shot                   ...
# ACTION_TYPE:turnaround_finger_roll_shot                ...
# ACTION_TYPE:turnaround_hook_shot                       ...
# ACTION_TYPE:turnaround_jump_shot                       ...
# SEASON_GAME_NUMBER                                     ...
# ...
# ACTION_TYPE:reverse_layup_shot                                         -0.025751
# ACTION_TYPE:reverse_slam_dunk_shot                                     -0.008565
# ACTION_TYPE:running_bank_shot                                          -0.014236
# ACTION_TYPE:running_dunk_shot                                           0.021218
# ACTION_TYPE:running_finger_roll_layup_shot                              0.082843
# ACTION_TYPE:running_finger_roll_shot                                   -0.004369
# ACTION_TYPE:running_hook_shot                                          -0.013360
# ACTION_TYPE:running_jump_shot                                          -0.023752
# ACTION_TYPE:running_layup_shot                                         -0.016565
# ACTION_TYPE:running_pull-up_jump_shot                                  -0.003812
# ACTION_TYPE:running_reverse_layup_shot                                 -0.005556
# ACTION_TYPE:running_slam_dunk_shot                                     -0.002241
# ACTION_TYPE:running_tip_shot                                           -0.002994
# ACTION_TYPE:slam_dunk_shot                                             -0.036444
# ACTION_TYPE:step_back_jump_shot                                         0.012757
# ACTION_TYPE:tip_layup_shot                                             -0.003170
# ACTION_TYPE:tip_shot                                                   -0.000893
# ACTION_TYPE:turnaround_bank_shot                                       -0.016264
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                         -0.002241
# ACTION_TYPE:turnaround_fadeaway_shot                                    0.061389
# ACTION_TYPE:turnaround_finger_roll_shot                                -0.003161
# ACTION_TYPE:turnaround_hook_shot                                        1.000000
# ACTION_TYPE:turnaround_jump_shot                                        0.021150
# SEASON_GAME_NUMBER                                                      0.028072
# CAREER_GAME_NUMBER                                                      0.087317
#
#                                                 ACTION_TYPE:turnaround_jump_shot  \
# SHOTS_MADE                                                              0.146655
# AWAY_GAME                                                               0.053858
# SEASON_OPPONENT:atl:1996-97                                            -0.023060
# SEASON_OPPONENT:atl:1997-98                                            -0.023060
# SEASON_OPPONENT:atl:1999-00                                            -0.016301
# SEASON_OPPONENT:atl:2000-01                                            -0.016301
# SEASON_OPPONENT:atl:2001-02                                            -0.023060
# SEASON_OPPONENT:atl:2002-03                                            -0.005776
# SEASON_OPPONENT:atl:2003-04                                             0.037716
# SEASON_OPPONENT:atl:2004-05                                            -0.016301
# SEASON_OPPONENT:atl:2005-06                                             0.002866
# SEASON_OPPONENT:atl:2006-07                                             0.154751
# SEASON_OPPONENT:atl:2007-08                                            -0.000375
# SEASON_OPPONENT:atl:2008-09                                             0.015147
# SEASON_OPPONENT:atl:2009-10                                             0.105679
# SEASON_OPPONENT:atl:2010-11                                             0.017270
# SEASON_OPPONENT:atl:2011-12                                            -0.016301
# SEASON_OPPONENT:atl:2012-13                                            -0.023060
# SEASON_OPPONENT:atl:2013-14                                            -0.016301
# SEASON_OPPONENT:atl:2014-15                                             0.040716
# SEASON_OPPONENT:atl:2015-16                                             0.010707
# SEASON_OPPONENT:bkn:2012-13                                            -0.007937
# SEASON_OPPONENT:bkn:2015-16                                             0.015771
# SEASON_OPPONENT:bos:1996-97                                            -0.016301
# SEASON_OPPONENT:bos:1997-98                                            -0.023060
# SEASON_OPPONENT:bos:1999-00                                            -0.023060
# SEASON_OPPONENT:bos:2001-02                                            -0.023060
# SEASON_OPPONENT:bos:2002-03                                             0.017660
# SEASON_OPPONENT:bos:2003-04                                            -0.023060
# SEASON_OPPONENT:bos:2004-05                                            -0.023060
# ...                                                                          ...
# ACTION_TYPE:pullup_jump_shot                                            0.041364
# ACTION_TYPE:putback_dunk_shot                                          -0.035528
# ACTION_TYPE:putback_layup_shot                                          0.014062
# ACTION_TYPE:putback_slam_dunk_shot                                      0.002026
# ACTION_TYPE:reverse_dunk_shot                                           0.058879
# ACTION_TYPE:reverse_layup_shot                                          0.067947
# ACTION_TYPE:reverse_slam_dunk_shot                                     -0.014516
# ACTION_TYPE:running_bank_shot                                           0.024318
# ACTION_TYPE:running_dunk_shot                                          -0.021697
# ACTION_TYPE:running_finger_roll_layup_shot                              0.013266
# ACTION_TYPE:running_finger_roll_shot                                    0.012389
# ACTION_TYPE:running_hook_shot                                          -0.000408
# ACTION_TYPE:running_jump_shot                                          -0.093093
# ACTION_TYPE:running_layup_shot                                          0.028371
# ACTION_TYPE:running_pull-up_jump_shot                                  -0.027732
# ACTION_TYPE:running_reverse_layup_shot                                 -0.011033
# ACTION_TYPE:running_slam_dunk_shot                                     -0.016301
# ACTION_TYPE:running_tip_shot                                            0.016235
# ACTION_TYPE:slam_dunk_shot                                             -0.120817
# ACTION_TYPE:step_back_jump_shot                                         0.069935
# ACTION_TYPE:tip_layup_shot                                             -0.023060
# ACTION_TYPE:tip_shot                                                   -0.054058
# ACTION_TYPE:turnaround_bank_shot                                        0.077958
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot                         -0.016301
# ACTION_TYPE:turnaround_fadeaway_shot                                    0.032020
# ACTION_TYPE:turnaround_finger_roll_shot                                -0.022992
# ACTION_TYPE:turnaround_hook_shot                                        0.021150
# ACTION_TYPE:turnaround_jump_shot                                        1.000000
# SEASON_GAME_NUMBER                                                      0.050394
# CAREER_GAME_NUMBER                                                      0.201415
#
#                                                 SEASON_GAME_NUMBER  \
# SHOTS_MADE                                                0.059012
# AWAY_GAME                                                 0.022408
# SEASON_OPPONENT:atl:1996-97                              -0.024709
# SEASON_OPPONENT:atl:1997-98                              -0.024709
# SEASON_OPPONENT:atl:1999-00                              -0.033038
# SEASON_OPPONENT:atl:2000-01                               0.018543
# SEASON_OPPONENT:atl:2001-02                               0.003515
# SEASON_OPPONENT:atl:2002-03                              -0.005434
# SEASON_OPPONENT:atl:2003-04                              -0.010654
# SEASON_OPPONENT:atl:2004-05                              -0.037904
# SEASON_OPPONENT:atl:2005-06                              -0.021956
# SEASON_OPPONENT:atl:2006-07                               0.001998
# SEASON_OPPONENT:atl:2007-08                               0.010399
# SEASON_OPPONENT:atl:2008-09                               0.027609
# SEASON_OPPONENT:atl:2009-10                              -0.008876
# SEASON_OPPONENT:atl:2010-11                               0.025544
# SEASON_OPPONENT:atl:2011-12                              -0.013573
# SEASON_OPPONENT:atl:2012-13                               0.027609
# SEASON_OPPONENT:atl:2013-14                              -0.036931
# SEASON_OPPONENT:atl:2014-15                              -0.031092
# SEASON_OPPONENT:atl:2015-16                              -0.026225
# SEASON_OPPONENT:bkn:2012-13                              -0.017825
# SEASON_OPPONENT:bkn:2015-16                              -0.036931
# SEASON_OPPONENT:bos:1996-97                              -0.029145
# SEASON_OPPONENT:bos:1997-98                              -0.034347
# SEASON_OPPONENT:bos:1999-00                              -0.023332
# SEASON_OPPONENT:bos:2001-02                               0.026921
# SEASON_OPPONENT:bos:2002-03                              -0.008187
# SEASON_OPPONENT:bos:2003-04                              -0.008876
# SEASON_OPPONENT:bos:2004-05                              -0.004745
# ...                                                            ...
# ACTION_TYPE:pullup_jump_shot                              0.008097
# ACTION_TYPE:putback_dunk_shot                             0.032472
# ACTION_TYPE:putback_layup_shot                            0.058919
# ACTION_TYPE:putback_slam_dunk_shot                       -0.015520
# ACTION_TYPE:reverse_dunk_shot                             0.013334
# ACTION_TYPE:reverse_layup_shot                           -0.006516
# ACTION_TYPE:reverse_slam_dunk_shot                       -0.018456
# ACTION_TYPE:running_bank_shot                             0.079688
# ACTION_TYPE:running_dunk_shot                             0.012761
# ACTION_TYPE:running_finger_roll_layup_shot               -0.032288
# ACTION_TYPE:running_finger_roll_shot                     -0.017354
# ACTION_TYPE:running_hook_shot                             0.017522
# ACTION_TYPE:running_jump_shot                             0.065050
# ACTION_TYPE:running_layup_shot                           -0.034855
# ACTION_TYPE:running_pull-up_jump_shot                    -0.005959
# ACTION_TYPE:running_reverse_layup_shot                   -0.048294
# ACTION_TYPE:running_slam_dunk_shot                        0.019517
# ACTION_TYPE:running_tip_shot                             -0.026530
# ACTION_TYPE:slam_dunk_shot                               -0.023865
# ACTION_TYPE:step_back_jump_shot                          -0.036240
# ACTION_TYPE:tip_layup_shot                               -0.005434
# ACTION_TYPE:tip_shot                                     -0.014370
# ACTION_TYPE:turnaround_bank_shot                         -0.009712
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot            0.003945
# ACTION_TYPE:turnaround_fadeaway_shot                     -0.031060
# ACTION_TYPE:turnaround_finger_roll_shot                  -0.000560
# ACTION_TYPE:turnaround_hook_shot                          0.028072
# ACTION_TYPE:turnaround_jump_shot                          0.050394
# SEASON_GAME_NUMBER                                        1.000000
# CAREER_GAME_NUMBER                                        0.018277
#
#                                                 CAREER_GAME_NUMBER
# SHOTS_MADE                                                0.194842
# AWAY_GAME                                                 0.007128
# SEASON_OPPONENT:atl:1996-97                              -0.060220
# SEASON_OPPONENT:atl:1997-98                              -0.054241
# SEASON_OPPONENT:atl:1999-00                              -0.030961
# SEASON_OPPONENT:atl:2000-01                              -0.023016
# SEASON_OPPONENT:atl:2001-02                              -0.027180
# SEASON_OPPONENT:atl:2002-03                              -0.019807
# SEASON_OPPONENT:atl:2003-04                              -0.009099
# SEASON_OPPONENT:atl:2004-05                              -0.005831
# SEASON_OPPONENT:atl:2005-06                              -0.001155
# SEASON_OPPONENT:atl:2006-07                               0.005100
# SEASON_OPPONENT:atl:2007-08                               0.014189
# SEASON_OPPONENT:atl:2008-09                               0.023396
# SEASON_OPPONENT:atl:2009-10                               0.029653
# SEASON_OPPONENT:atl:2010-11                               0.039298
# SEASON_OPPONENT:atl:2011-12                               0.031131
# SEASON_OPPONENT:atl:2012-13                               0.052330
# SEASON_OPPONENT:atl:2013-14                               0.038118
# SEASON_OPPONENT:atl:2014-15                               0.038794
# SEASON_OPPONENT:atl:2015-16                               0.041048
# SEASON_OPPONENT:bkn:2012-13                               0.049700
# SEASON_OPPONENT:bkn:2015-16                               0.040428
# SEASON_OPPONENT:bos:1996-97                              -0.043244
# SEASON_OPPONENT:bos:1997-98                              -0.054799
# SEASON_OPPONENT:bos:1999-00                              -0.042444
# SEASON_OPPONENT:bos:2001-02                              -0.025825
# SEASON_OPPONENT:bos:2002-03                              -0.019966
# SEASON_OPPONENT:bos:2003-04                              -0.012513
# SEASON_OPPONENT:bos:2004-05                              -0.005419
# ...                                                            ...
# ACTION_TYPE:pullup_jump_shot                              0.413002
# ACTION_TYPE:putback_dunk_shot                             0.041883
# ACTION_TYPE:putback_layup_shot                            0.096672
# ACTION_TYPE:putback_slam_dunk_shot                        0.008706
# ACTION_TYPE:reverse_dunk_shot                            -0.032605
# ACTION_TYPE:reverse_layup_shot                            0.014500
# ACTION_TYPE:reverse_slam_dunk_shot                        0.087066
# ACTION_TYPE:running_bank_shot                             0.129027
# ACTION_TYPE:running_dunk_shot                            -0.002940
# ACTION_TYPE:running_finger_roll_layup_shot                0.054626
# ACTION_TYPE:running_finger_roll_shot                     -0.014090
# ACTION_TYPE:running_hook_shot                             0.053031
# ACTION_TYPE:running_jump_shot                            -0.326392
# ACTION_TYPE:running_layup_shot                            0.082085
# ACTION_TYPE:running_pull-up_jump_shot                     0.072070
# ACTION_TYPE:running_reverse_layup_shot                    0.062437
# ACTION_TYPE:running_slam_dunk_shot                        0.036991
# ACTION_TYPE:running_tip_shot                             -0.013906
# ACTION_TYPE:slam_dunk_shot                               -0.339379
# ACTION_TYPE:step_back_jump_shot                           0.289221
# ACTION_TYPE:tip_layup_shot                                0.059903
# ACTION_TYPE:tip_shot                                     -0.170223
# ACTION_TYPE:turnaround_bank_shot                          0.166041
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot            0.042795
# ACTION_TYPE:turnaround_fadeaway_shot                      0.403437
# ACTION_TYPE:turnaround_finger_roll_shot                  -0.005492
# ACTION_TYPE:turnaround_hook_shot                          0.087317
# ACTION_TYPE:turnaround_jump_shot                          0.201415
# SEASON_GAME_NUMBER                                        0.018277
# CAREER_GAME_NUMBER                                        1.000000
#
# [645 rows x 645 columns]

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# from class

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.5)

lr = LinearRegression()
lr.fit(X_train, y_train)

lr_r2_train = lr.score(X_train, y_train)
lr_r2_test = lr.score(X_test, y_test)

print "R2 on train: {}".format(lr_r2_train)
print "R2 on test: {}".format(lr_r2_test)
# Out:
# R2 on train: 0.890785724923
# R2 on test: 0.223015602856

# %% [markdown]
# ### what's causing this
#
# - to many predictor columns
# - too few rows compared to columns

# %%
sns.heatmap(x.iloc[:,60:100].corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-93e1aa1b8ab8> in <module>()
# ----> 1 sns.heatmap(x.iloc[:,60:100].corr())
#
# NameError: name 'x' is not defined

# %% [markdown]
# # <font color=blue> Interlude</font> - Slides
#
# Sit back and enjoy the show...
#
# ----
# # <font color=blue> Part II</font> - Addressing the problem

# %% [markdown]
# ---
#
# ### 6. Try fitting ealuating a  `Ridge` model instead of a standard `LinearRegression`
# The ridge regression is a model _similar_ to the standard linear regression, but for now let it remain shrouded in an \*air\* of mystery.
#
# Is it better than the Linear regression? On the training set? On the test set? Why do you think that is?

# %%
# A:

X2_train, X2_test, y2_train, y2_test = train_test_split(X, y, test_size= 0.25)

lm = Ridge(alpha = 100)

#X = df 
#y = target 

model = lm.fit(X2_train, y2_train)

score1 = model.score (X2_test, y2_test)
score2 = model.score (X2_test, y2_test)
print score1, score2
# Out:
# 0.624210885319 0.624210885319

# %% [markdown]
# ---
# ### 7. Examine your ridge model's coefficients
#
# Does anything jump out at you? Use any the tools we've learned so far like histograms, barplots, and other descriptive statistics to compare the ridge model's fit to the linear regression we used earlier.

# %% [markdown]
# ---
#
# ### 8. Play around with the `alpha` hyper parameter
#
# How does this impact the coefficients of the fit model?
#
# #### EX:
# ```python
# ridge = Ridge(alpha = 10.0)
# ```
#
# Some good values to try might be `0`, `0.1`, `1.0`, `10`, `100`

# %%
# A:

# %% [markdown]
# ---
#
# ### 9. Fit a `Lasso` model and examine it's coefficients
#
# Is it better than the Linear regression? Is it better than Ridge? What do the differences in results imply about the issues with the dataset?
#
# - Show the coefficient for variables, ordered from largest to smallest coefficient by absolute value.
# - What percent of the variables in the original dataset are "zeroed-out" by the lasso?
# - What are the most important predictors for how many shots Kobe made in a game?

# %%
# A:

# %% [markdown]
# ---
#
# ### 10. Tune the alpha for your `Lasso` model
#
# How does this influence the coefficients? The model performance on the train and the test sets?

# %%
# A:

# %% [markdown]
# ---
#
# ### 11. Synthesize what you've discovered
#
# Write a couple of sentences telling the story:
# - How did a standard linear regression perform on the Kobe dataset? What qualities of this dataset caused these results>
# - How did a Ridge perform in comparison? What clues could you glean from its coefficients? How does `alpha` seem to dictate the coefficients?
# - What about the the `Lasso`?
# - When will be useful?

# %%
# A:
